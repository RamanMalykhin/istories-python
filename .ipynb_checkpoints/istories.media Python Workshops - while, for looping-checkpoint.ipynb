# %%
#the next exercise seems to be about while loops

# %%
line = "Python tutorial"
len(line)
# Out:
# 15

# %%
line[0]
# Out:
# 'P'

# %%
line[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-e443a97e5f37> in <module>
# ----> 1 line[15]
#
# IndexError: string index out of range

# %%
line[14]
# Out:
# 'l'

# %%
counter = 0
while counter < len(line)
    line(counter)
    counter = counter + 1
# Out:
#   File "<ipython-input-39-43e63050a6ee>", line 2
#     while counter < len(line)
#                              ^
# SyntaxError: invalid syntax

# %%
#missed a colon
counter = 0
while counter < len(line):
    line[counter]
    counter = counter + 1

# %%
#is that a print thing again?

# %%
counter = 0
while counter < len(line):
    print(line[counter])
    counter = counter + 1
# Out:
# P
# y
# t
# h
# o
# n
#
# t
# u
# t
# o
# r
# i
# a
# l

# %%
#yeah, it was a print thing

# %%
#looks like print is the only reliable way to handle text output then?

# %%
#but apparently everything I just did can be done in like two lines

# %%
for counter2 in line:
    print(counter2)
# Out:
# P
# y
# t
# h
# o
# n
#
# t
# u
# t
# o
# r
# i
# a
# l

# %%
#W H O A
#this is impressive
#I really need to look into how exactly Python interprets fors later

# %%
#ins alone are also cool

# %%
english_consonants = "bcdfghklmnpqrstvwxz"

# %%
counter = 0
while counter < len(line):
    if line[counter] in english_consonants:
        print(line[counter])
    counter = counter + 1
# Out:
# t
# h
# n
# t
# t
# r
# l

# %%
#cool but I lost a P - I expected to get 'Pthnttrl'- so in is register sensitive

# %%
counter = 0
while counter < len(line):
    if line[counter] in english_consonants:
        print(line[counter])
    elif line[counter] in english_consonants.upper():
        print(line[counter])
    counter = counter + 1
# Out:
# P
# t
# h
# n
# t
# t
# r
# l

# %%
#I can also stick them all in one string
counter = 0
while counter < len(line):
    if line[counter] in english_consonants:
        consonant_str = consonant_str + print(line[counter])
    elif line[counter] in english_consonants.upper():
        consonant_str = consonant_str + print(line[counter])
    counter = counter + 1
print(consonant_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-bc0828c9d416> in <module>
#       5         consonant_str = consonant_str + print(line[counter])
#       6     elif line[counter] in english_consonants.upper():
# ----> 7         consonant_str = consonant_str + print(line[counter])
#       8     counter = counter + 1
#       9 print(consonant_str)
#
# NameError: name 'consonant_str' is not defined

# %%
#also fixed the improper prints
counter = 0
consonant_str =''
while counter < len(line):
    if line[counter] in english_consonants:
        consonant_str = consonant_str + line[counter]
    elif line[counter] in english_consonants.upper():
        consonant_str = consonant_str + line[counter]
    counter = counter + 1
print(consonant_str)
# Out:
# Pthnttrl

# %%
#I can also nest loops, much like in VBA
#assume we have two sets of data - heights of females and males
#assume for every male I want to know if he's taller than any females
male_data = [175, 150, 184, 166, 192]
female_data = [162, 171, 177, 165, 170]

# %%
type(male_data)
# Out:
# list

# %%
#does len work on lists?

# %%
len(male_data)
# Out:
# 5

# %%
#yes it does!

# %%
#which means I can recycle much of what I have already done

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter <len(female_data):
            if male_data[m_counter]>female_data[f_counter]:
            print("Male nr ",m_counter, "is taller than female nr ",f_counter, "by " (male_data[m_counter]-female_data[f_counter]), "cm") 
    f_counter =+ 1
    m_counter =+ 1
# Out:
#   File "<ipython-input-9-673c2db1b153>", line 7
#     print("Male nr ",m_counter, "is taller than female nr ",f_counter, "by " (male_data[m_counter]-female_data[f_counter]), "cm")
#     ^
# IndentationError: expected an indented block

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter < len(female_data):
        if male_data[m_counter]>female_data[f_counter]:
            diff = male_data[m_counter] - female_data[f_counter] 
            print("Male nr ",m_counter,"is taller than female nr ",f_counter,"by ",diff,"cm") 
            f_counter =+1
    m_counter =+1
# Out:
# Male nr  0 is taller than female nr  0 by  13 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# ...

# %%
male_data[0]
# Out:
# 175

# %%
female_data[0]
# Out:
# 162

# %%
#so why the hell does it go into infinity?

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter < len(female_data):
        if male_data[m_counter]>female_data[f_counter]:
            diff = male_data[m_counter] - female_data[f_counter] 
            print("Male nr ",m_counter,"is taller than female nr ",f_counter,"by ",diff,"cm") 
        f_counter += 1
    m_counter += 1
# Out:
# Male nr  0 is taller than female nr  0 by  13 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  3 by  10 cm
# Male nr  0 is taller than female nr  4 by  5 cm

# %%
male_data
# Out:
# [175, 150, 184, 166, 192]

# %%
female_data
# Out:
# [162, 171, 177, 165, 170]

# %%
#well, at least i was correct on all counts for 0, but why doesn't it iterate through other males?

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    print(male_data[m_counter])
    m_counter += 1
# Out:
# 175
# 150
# 184
# 166
# 192

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter < len(female_data):
        print(female_data[f_counter])
        f_counter += 1
    m_counter += 1
#if this works as I expect, it will print all female heights 5 times
# Out:
# 162
# 171
# 177
# 165
# 170

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter < len(female_data):
        print(female_data[f_counter])
        f_counter += 1
    f_counter = 0
    m_counter += 1
# Out:
# 162
# 171
# 177
# 165
# 170
# 162
# 171
# 177
# 165
# 170
# 162
# 171
# 177
# 165
# 170
# 162
# 171
# 177
# 165
# 170
# 162
# 171
# 177
# 165
# 170

# %%
#better!

# %%
m_counter = 0
f_counter = 0

while m_counter < len(male_data):
    while f_counter < len(female_data):       
        if male_data[m_counter]>female_data[f_counter]:
            diff = male_data[m_counter] - female_data[f_counter] 
            print("Male nr ",m_counter,"is taller than female nr ",f_counter,"by ",diff,"cm") 
        f_counter += 1
    f_counter = 0
    m_counter += 1
# Out:
# Male nr  0 is taller than female nr  0 by  13 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  3 by  10 cm
# Male nr  0 is taller than female nr  4 by  5 cm
# Male nr  2 is taller than female nr  0 by  22 cm
# Male nr  2 is taller than female nr  1 by  13 cm
# Male nr  2 is taller than female nr  2 by  7 cm
# Male nr  2 is taller than female nr  3 by  19 cm
# Male nr  2 is taller than female nr  4 by  14 cm
# Male nr  3 is taller than female nr  0 by  4 cm
# Male nr  3 is taller than female nr  3 by  1 cm
# Male nr  4 is taller than female nr  0 by  30 cm
# Male nr  4 is taller than female nr  1 by  21 cm
# Male nr  4 is taller than female nr  2 by  15 cm
# Male nr  4 is taller than female nr  3 by  27 cm
# Male nr  4 is taller than female nr  4 by  22 cm

# %%
#hooray, it worked
#but people on stackoverflow say that iterating through loops with counters is not pythonic

# %%
for m_counter, m_height in enumerate(male_data):
    for f_counter, f_height in enumerate(female_data):
        if m_height>f_height:
            diff = m_height - f_height 
            print("Male nr ",m_counter,"is taller than female nr ",f_counter,"by ",diff,"cm")
# Out:
# Male nr  0 is taller than female nr  0 by  13 cm
# Male nr  0 is taller than female nr  1 by  4 cm
# Male nr  0 is taller than female nr  3 by  10 cm
# Male nr  0 is taller than female nr  4 by  5 cm
# Male nr  2 is taller than female nr  0 by  22 cm
# Male nr  2 is taller than female nr  1 by  13 cm
# Male nr  2 is taller than female nr  2 by  7 cm
# Male nr  2 is taller than female nr  3 by  19 cm
# Male nr  2 is taller than female nr  4 by  14 cm
# Male nr  3 is taller than female nr  0 by  4 cm
# Male nr  3 is taller than female nr  3 by  1 cm
# Male nr  4 is taller than female nr  0 by  30 cm
# Male nr  4 is taller than female nr  1 by  21 cm
# Male nr  4 is taller than female nr  2 by  15 cm
# Male nr  4 is taller than female nr  3 by  27 cm
# Male nr  4 is taller than female nr  4 by  22 cm
